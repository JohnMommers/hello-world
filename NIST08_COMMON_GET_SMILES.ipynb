# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnMommers/hello-world/blob/master/NIST08_COMMON_GET_SMILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## SCRIPT TO GET ALL SMILES FOR NIST08 COMMON

# %%
# %%bash
# wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# chmod +x Miniconda3-latest-Linux-x86_64.sh
# ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# conda config --set always_yes yes --set changeps1 no
# conda install -q -y -c conda-forge python=3.7
# conda install -q -y -c conda-forge rdkit==2020.09.2
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py38h27cfd23_1003
#     - ca-certificates==2020.10.14=0
#     - certifi==2020.6.20=pyhd3eb1b0_3
#     - cffi==1.14.3=py38h261ae71_2
#     - chardet==3.0.4=py38h06a4308_1003
#     - conda-package-handling==1.7.2=py38h03888b9_0
#     - conda==4.9.2=py38h06a4308_0
#     - cryptography==3.2.1=py38h3c74f83_1
#     - idna==2.10=py_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20191231=h14c3975_1
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1h=h7b6447c_0
#     - pip==20.2.4=py38h06a4308_0
#     - pycosat==0.6.3=py38h7b6447c_1
#     - pycparser==2.20=py_2
#     - pyopenssl==19.1.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py38h06a4308_0
# ...

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
from rdkit import Chem

# %%
pip install deepchem
# Out:
# ...
#      |████████████████████████████████| 531 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 22.3 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 302 kB 51.9 MB/s
# ...
#      |████████████████████████████████| 27.4 MB 1.4 MB/s
# ...

# %%
pip install cirpy
# Out:
# ...
#   Created wheel for cirpy: filename=CIRpy-1.0.2-py3-none-any.whl size=7268 sha256=60ce2d36e6e132a5ba1cf271e892c5f5e0d25d36515e0893309f87122e904355
#   Stored in directory: /root/.cache/pip/wheels/fb/e2/b9/19a742f4ecd98caa1bae9cc34a462b24b6fed35be23bddc1d6
# Successfully built cirpy
# ...

# %%
import re
import pandas as pd
import numpy as np
import pickle
import cirpy as cp

# %%
# load NIST08_Common_no_smiles
import pickle
filename = '/content/drive/MyDrive/NIST/nist_08_Common_no_smiles'     
infile = open(filename,'rb')
ms = pickle.load(infile)
infile.close()

# %%
#### DON'T RUN THIS !!!!!
#### DELETE OLD FILE AND CREATE NEW FILE !!!!!

smiles=[]
# Update the file with the new smiles
# with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
#    pickle.dump(smiles, fp)

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)
# Out:
# 115722
# 0 115722 CCCCCCCCCCC(CC)OC(=O)CCc1ccccc1
# 1 115723 CCCCCCCCCC(CCC)OC(=O)CCc1ccccc1
# 2 115724 CCCCCCCCCCC(CCC)OC(=O)CCc1ccccc1
# 3 115725 CCC(CC)OC(=O)CCc1ccccc1
# 4 115726 O=C(CCc1ccccc1)OC2CCCC2
# 5 115727 CCC(CC)CCC(CC)OC(=O)CCc1ccccc1
# 6 115728 None
# 7 115729 CCOC(=O)NCc1ccccc1
# 8 115730 OC1C2CC3CC1CC(C2)C3O
# 9 115731 COC(=O)C(Cc1ccccc1)C(C(=O)OC)c2ccccc2
# 10 115732 COCc1ccc(cc1)C(C)N
# 11 115733 CC1(C)C(C=C(Cl)Cl)C1C(=O)Nc2sc3ccccc3n2
# 12 115734 COc1cc(CCNC(=O)Cc2ccccc2)ccc1O
# 13 115735 COc1ccc(CCNC(=O)Cc2ccccc2)cc1O
# 14 115736 CCCCCCc1cccc(c1)C(=O)OC
# 15 115737 COc1ccc(C)cc1C=O
# 16 115738 COC(=O)c1cccc(CCCc2cccc(c2)C(=O)OC)c1
# 17 115739 O=C(CCCc1ccccc1)Nc2sc3ccccc3n2
# 18 115740 [O-][N+](=O)c1ccc(cc1)C(=O)OCc2ccccc2
# 19 115741 O=C(Cc1ccccc1)Nc2sc3ccccc3n2
# 20 115742 Cc1ccc(cn1)C(C)=NO
# 21 115743 Cc1ccc(cc1CCc2cc(ccc2C)[N+]([O-])=O)[N+]([O-])=O
# 22 115744 Cl.NC1C2CC3CC(C2)CC1C3
# 23 115745 Cc1cccnc1NC(=S)NCC2CCCO2
# 24 115746 NC1C2CC3CC(C2)CC1C3
# ...

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)
# Out:
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# 5000 100722 Cc1[nH]c2ccccc2c1CCN[S](=O)(=O)c3ccc4OC(=O)C=Cc4c3
# 5001 100723 O=Cc1ccc2[nH]ccc2c1
# 5002 100724 CCOc1ccc(cc1C(C)C)[S](=O)(=O)NCCc2c(C)[nH]c3ccccc23
# 5003 100725 CCCCCCCCCOC(=O)[C@H](CCC)NC(=O)OCC
# 5004 100726 CC(C)COC(=O)CCCCC(=O)Oc1ccc2ccccc2c1
# 5005 100727 CCCCOC(=O)CCCCC(=O)Oc1ccc2ccccc2c1
# 5006 100728 CCCCCOC(=O)CCCCC(=O)Oc1ccc2ccccc2c1
# 5007 100729 CCCCCCCCCCOC(=O)[C@H](C(C)C)N(C)C(=O)OC
# 5008 100730 CCCCCCCCCCCCOC(=O)[C@H](C(C)C)N(C)C(=O)OC
# 5009 100731 CCCCCCCCCCCCCCOC(=O)[C@H](C(C)C)N(C)C(=O)OC
# 5010 100732 CCCCCCCCCCCCCCCOC(=O)[C@H](C(C)C)N(C)C(=O)OC
# 5011 100733 CCCCCCCCCCCCCCCCOC(=O)[C@H](C(C)C)N(C)C(=O)OC
# 5012 100734 CCCCCCCCCCCCCCCCCOC(=O)[C@H](C(C)C)N(C)C(=O)OC
# 5013 100735 CCCCCCCCCCCCCCCCCCOC(=O)[C@H](C(C)C)N(C)C(=O)OC
# 5014 100736 O=C(CCC1CCCC1)Oc2ccc3ccccc3c2
# 5015 100737 ClCCCC(=O)Oc1ccc2ccccc2c1
# 5016 100738 BrCCCC(=O)Oc1ccc2ccccc2c1
# 5017 100739 BrCCCCCC(=O)Oc1ccc2ccccc2c1
# ...

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)
# Out:
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# 5000 110722 CCCCCCCOC(=O)C1(CCCC1)NC(=O)OCC
# 5001 110723 CCCCCCCCOC(=O)C1(CCCC1)NC(=O)OCC
# 5002 110724 CCCCCCCCCOC(=O)C1(CCCC1)NC(=O)OCC
# 5003 110725 CCCCCCCCCCOC(=O)C1(CCCC1)NC(=O)OCC
# 5004 110726 CCCCCCCCCCCOC(=O)C1(CCCC1)NC(=O)OCC
# 5005 110727 CC1CCC(C(C)C)C(C1)OC(=O)CCC2CCC(=O)N2
# 5006 110728 CCN1N=C(OC)N(CC)C1=O
# 5007 110729 CCCCN(CCCC)CC=CCO
# 5008 110730 NCCCCCCCCCCCC(O)=O
# 5009 110731 None
# 5010 110732 Cc1ccc(S)c(S)c1
# 5011 110733 C[S](=O)(=O)C1CC(=C)CC1c2ccccc2
# 5012 110734 C1CC2(CC2c3ccccc3)CC1=Cc4ccccc4
# 5013 110735 COC(=O)[C@@H]1CC(=C)C[C@H]1c2ccccc2
# 5014 110736 COC(=O)C1N2C(SC1(C)C)N(CC2=O)C(=O)Cc3ccccc3
# 5015 110737 CC1(C2C3C4CC(C=C4)C3C12)c5ccccc5
# 5016 110738 CC(C)=C1C=CC2CC(=CC#N)C12
# 5017 110739 C[S](=O)(=O)c1nc(nn1Cc2ccccc2)[N+]([O-])=O
# 5018 110740 CC1(C2C3C4CC(C=C4)C3C12)c5ccccc5
# 5019 110741 C=C1C[C@H]([C@@H](C1)[S](=O)(=O)c2ccccc2)c3ccccc3
# ...

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)
# Out:
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# 2906 118628 CCCCCCC1C(CCCC)Cc2ccccc12
# 2907 118629 CN1C(=C(/O)Nc2ccccn2)/C(=O)c3ccccc3[S]1(=O)=O
# 2908 118630 O=CC1=CC(=O)Nc2ccccc12
# 2909 118631 Nc1nc(nc2ccccc12)N3CCN(CC3)CC=Cc4ccccc4
# 2910 118632 CC12CC3CC(C)(C1)CC(C3)(C2)C#C
# 2911 118633 Oc1ccccc1C=C2C(=O)NN(C2=O)c3cccc(Cl)c3
# 2912 118634 CC(=O)OC1CCCCC1N=C2C=CC=CN2O
# 2913 118635 None
# 2914 118636 None
# 2915 118637 Cc1ccc(cc1)N2CC(CC2=O)C(=O)NN=Cc3ccc4OCOc4c3
# 2916 118638 CCc1ccccc1NC(=O)c2ccc(cc2)C(F)(F)F
# 2917 118639 CCc1ccccc1NC(=O)c2cccc(c2)C(F)(F)F
# 2918 118640 Cc1cccc(c1)N(CCO)CCC#N
# 2919 118641 Cc1ccccc1N2CC(CC2=O)C(=O)N\N=C/c3ccc(Br)cc3
# 2920 118642 CCCCCCC(C=Cc1ccc(OC)cc1)=NNC(N)=O
# 2921 118643 CC1=C(CBr)C(=O)c2ccccc2O1
# 2922 118644 FC(F)(F)c1ccc(cc1)C(=O)OCc2ccc(Cl)cc2
# 2923 118645 OC(c1ccc(cc1)C(F)(F)F)c2ccc(cc2)C(F)(F)F
# 2924 118646 CCCCN(CCCC)C(=O)C1=Cc2ccccc2OC1=O
# 2925 118647 NC(=O)CC1NC(=S)NC1=O
# ...

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)

# %%
# load the file with the smiles 
with open ('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'rb') as fp:
    smiles = pickle.load(fp)

# add new smiles to the file 
start = len(smiles)
print (start)
c=0
for i in ms['Name'][start:start+10000]:
  s = cp.resolve(i,'smiles')
  smiles.append(s)
  print (c, start+c, s)
  c=c+1

# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)

# %%
len(smiles)
# Update the file with the new smiles
with open('/content/drive/MyDrive/NIST/nist_08_Common_smiles.pkl', 'wb') as fp:
    pickle.dump(smiles, fp)

# %%
a = len(smiles)
ms_new = ms[0:a]
ms_new['smiles'] = smiles
ms_new
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                      Name  ...                                     smiles
# 0                            Ethyl 3-ethoxy-cis-crotonate  ...                        CCOC(/C)=C/C(=O)OCC
# 1                         Ethanone, 1-(3-methyloxiranyl)-  ...                               CC1OC1C(C)=O
# 2                    2-Pentanone, 5-(1,2-propadienyloxy)-  ...                   CC(=O)CCCO[CH]=[C]=[CH2]
# 3                     n-Butyl (1,1-dimethylbutyl) sulfide  ...                            CCCCSC(C)(C)CCC
# ...

# %%
ms_new.loc[0]
